# %% [markdown]
# ## Install EasyOcr

# %%
# !pip install torch torchvision torchaudio easyocr
# Out:
# ...
# [notice] A new release of pip is available: 25.1.1 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Import libraries

# %%
import os
import shutil
import matplotlib.pyplot as plt
import cv2
import numpy as np
import easyocr
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 6
#       4 import cv2
#       5 import numpy as np
# ----> 6 import easyocr
#
# File ~\anaconda3\Lib\site-packages\easyocr\__init__.py:1
# ----> 1 from .easyocr import Reader
#       3 __version__ = '1.7.2'
#
# File ~\anaconda3\Lib\site-packages\easyocr\easyocr.py:3
#       1 # -*- coding: utf-8 -*-
# ----> 3 from .recognition import get_recognizer, get_text
#       4 from .utils import group_text_box, get_image_list, calculate_md5, get_paragraph,\
#       5                    download_and_unzip, printProgressBar, diff, reformat_input,\
#       6                    make_rotated_img_list, set_result_with_confidence,\
#       7                    reformat_input_batched, merge_to_free
#       8 from .config import *
#
# File ~\anaconda3\Lib\site-packages\easyocr\recognition.py:2
#       1 from PIL import Image
# ...

# %% [markdown]
# ## Perform Ocr, extract text and draw bounding box
